# %%
import pandas as pd

# %%
df = pd.read_csv(r"/Users/mirage/Documents/GitHub/code/decentralized_energy_transition/Stromerzeuger_100001_bis_125000.csv" , delimiter=';', encoding='utf-8')
df
# Out:
# /var/folders/_m/yjh6hk99473cjm7p55pxz9hw0000gn/T/ipykernel_12077/761291144.py:1: DtypeWarning: Columns (48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"/Users/mirage/Documents/GitHub/code/decentralized_energy_transition/Stromerzeuger_100001_bis_125000.csv" , delimiter=';', encoding='utf-8')
#       MaStR-Nr. der Einheit Anzeige-Name der Einheit Betriebs-Status  \
# 0           SEE987333197686        PV Maschinenhalle      In Betrieb
# 1           SEE900142280806             Wintergarten      In Betrieb
# 2           SEE950622581053                      Sol      In Betrieb
# 3           SEE987490315794                      Byd      In Betrieb
# 4           SEE967921459426                 Hausdach      In Betrieb
# ...                     ...                      ...             ...
# 24995       SEE989544154205                   Stall2      In Betrieb
# 24996       SEE932458982419                    57858      In Betrieb
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 50 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   MaStR-Nr. der Einheit                   25000 non-null  object
#  1   Anzeige-Name der Einheit                24999 non-null  object
#  2   Betriebs-Status                         25000 non-null  object
#  3   Energieträger                           25000 non-null  object
#  4   Bruttoleistung der Einheit              25000 non-null  object
#  5   Nettonennleistung der Einheit           25000 non-null  object
#  6   Inbetriebnahmedatum der Einheit         25000 non-null  object
#  7   Registrierungsdatum der Einheit         25000 non-null  object
#  8   Bundesland                              24998 non-null  object
#  9   Postleitzahl                            24924 non-null  float64
# ...

# %%
df.dtypes
# Out:
# MaStR-Nr. der Einheit                             object
# Anzeige-Name der Einheit                          object
# Betriebs-Status                                   object
# Energieträger                                     object
# Bruttoleistung der Einheit                        object
# Nettonennleistung der Einheit                     object
# Inbetriebnahmedatum der Einheit           datetime64[ns]
# Registrierungsdatum der Einheit           datetime64[ns]
# Bundesland                                        object
# Postleitzahl                                     float64
# Ort                                               object
# Straße                                            object
# Hausnummer                                        object
# Gemarkung                                         object
# Flurstück                                         object
# Gemeindeschlüssel                                float64
# ...

# %%
df.columns.get_indexer
# Out:
# <bound method Index.get_indexer of Index(['MaStR-Nr. der Einheit', 'Anzeige-Name der Einheit', 'Betriebs-Status',
#        'Energieträger', 'Bruttoleistung der Einheit',
#        'Nettonennleistung der Einheit', 'Inbetriebnahmedatum der Einheit',
#        'Registrierungsdatum der Einheit', 'Bundesland', 'Postleitzahl', 'Ort',
#        'Straße', 'Hausnummer', 'Gemarkung', 'Flurstück', 'Gemeindeschlüssel',
#        'Koordinate: Breitengrad (WGS84)', 'Koordinate: Längengrad (WGS84)',
#        'Anzahl der Solar-Module', 'Hauptausrichtung der Solar-Module',
#        'Name des Windparks', 'Nabenhöhe der Windenergieanlage',
#        'Rotordurchmesser der Windenergieanlage',
#        'Hersteller der Windenergieanlage', 'Typenbezeichnung',
#        'Hauptbrennstoff der Einheit', 'Nutzbare Speicherkapazität in kWh',
#        'Technologie der Stromerzeugung', 'Lage der Einheit',
#        'Letzte Aktualisierung', 'Datum der endgültigen Stilllegung',
# ...

# %%
df.isna().sum()
# Out:
# MaStR-Nr. der Einheit                         0
# Anzeige-Name der Einheit                      1
# Betriebs-Status                               0
# Energieträger                                 0
# Bruttoleistung der Einheit                    0
# Nettonennleistung der Einheit                 0
# Inbetriebnahmedatum der Einheit               0
# Registrierungsdatum der Einheit               0
# Bundesland                                    2
# Postleitzahl                                 76
# Ort                                          76
# Straße                                    22376
# Hausnummer                                22544
# Gemarkung                                 24411
# Flurstück                                 24127
# Gemeindeschlüssel                            76
# Koordinate: Breitengrad (WGS84)           21712
# Koordinate: Längengrad (WGS84)            21712
# Anzahl der Solar-Module                    3615
# Hauptausrichtung der Solar-Module          3504
# ...

# %%
df.isna().sum().count
# Out:
# <bound method Series.count of MaStR-Nr. der Einheit                         0
# Anzeige-Name der Einheit                      1
# Betriebs-Status                               0
# Energieträger                                 0
# Bruttoleistung der Einheit                    0
# Nettonennleistung der Einheit                 0
# Inbetriebnahmedatum der Einheit               0
# Registrierungsdatum der Einheit               0
# Bundesland                                    2
# Postleitzahl                                 76
# Ort                                          76
# Straße                                    22376
# Hausnummer                                22544
# Gemarkung                                 24411
# Flurstück                                 24127
# Gemeindeschlüssel                            76
# Koordinate: Breitengrad (WGS84)           21712
# Koordinate: Längengrad (WGS84)            21712
# Anzahl der Solar-Module                    3615
# ...

# %%
df.isna().index
df
# Out:
#       MaStR-Nr. der Einheit Anzeige-Name der Einheit Betriebs-Status  \
# 0           SEE987333197686        PV Maschinenhalle      In Betrieb
# 1           SEE900142280806             Wintergarten      In Betrieb
# 2           SEE950622581053                      Sol      In Betrieb
# 3           SEE987490315794                      Byd      In Betrieb
# 4           SEE967921459426                 Hausdach      In Betrieb
# ...                     ...                      ...             ...
# 24995       SEE989544154205                   Stall2      In Betrieb
# 24996       SEE932458982419                    57858      In Betrieb
# 24997       SEE984925713514                Stalldach      In Betrieb
# 24998       SEE975552487855                     Dach      In Betrieb
# 24999       SEE940494553968              PV Zimmerei      In Betrieb
#
#                   Energieträger Bruttoleistung der Einheit  \
# 0      Solare Strahlungsenergie                      27,38
# ...

# %%
def convert_columns_to_datetime(df, columns):
    for column in columns:
        df[column] = pd.to_datetime(df[column],format="%d/%m/%Y", errors="coerce")
    return df
columns = ["Inbetriebnahmedatum der Einheit" , "Registrierungsdatum der Einheit"]
convert_columns_to_datetime(df, columns)
# Out:
#       MaStR-Nr. der Einheit Anzeige-Name der Einheit Betriebs-Status  \
# 0           SEE987333197686        PV Maschinenhalle      In Betrieb
# 1           SEE900142280806             Wintergarten      In Betrieb
# 2           SEE950622581053                      Sol      In Betrieb
# 3           SEE987490315794                      Byd      In Betrieb
# 4           SEE967921459426                 Hausdach      In Betrieb
# ...                     ...                      ...             ...
# 24995       SEE989544154205                   Stall2      In Betrieb
# 24996       SEE932458982419                    57858      In Betrieb
# 24997       SEE984925713514                Stalldach      In Betrieb
# 24998       SEE975552487855                     Dach      In Betrieb
# 24999       SEE940494553968              PV Zimmerei      In Betrieb
#
#                   Energieträger Bruttoleistung der Einheit  \
# 0      Solare Strahlungsenergie                      27,38
# ...

# %%
df.head()
# Out:
#   MaStR-Nr. der Einheit Anzeige-Name der Einheit Betriebs-Status  \
# 0       SEE987333197686        PV Maschinenhalle      In Betrieb
# 1       SEE900142280806             Wintergarten      In Betrieb
# 2       SEE950622581053                      Sol      In Betrieb
# 3       SEE987490315794                      Byd      In Betrieb
# 4       SEE967921459426                 Hausdach      In Betrieb
#
#               Energieträger Bruttoleistung der Einheit  \
# 0  Solare Strahlungsenergie                      27,38
# 1  Solare Strahlungsenergie                       4,56
# 2  Solare Strahlungsenergie                       9,44
# 3                  Speicher                        4,6
# 4  Solare Strahlungsenergie                       9,22
#
#   Nettonennleistung der Einheit Inbetriebnahmedatum der Einheit  \
# 0                          23,2                      2008-03-20
# 1                           4,2                      2013-11-19
# ...

# %%
df.dtypes
# Out:
# MaStR-Nr. der Einheit                             object
# Anzeige-Name der Einheit                          object
# Betriebs-Status                                   object
# Energieträger                                     object
# Bruttoleistung der Einheit                        object
# Nettonennleistung der Einheit                     object
# Inbetriebnahmedatum der Einheit           datetime64[ns]
# Registrierungsdatum der Einheit           datetime64[ns]
# Bundesland                                        object
# Postleitzahl                                     float64
# Ort                                               object
# Straße                                            object
# Hausnummer                                        object
# Gemarkung                                         object
# Flurstück                                         object
# Gemeindeschlüssel                                float64
# ...

# %%
df["Bruttoleistung der Einheit"] = df["Bruttoleistung der Einheit"].str.replace(',', '.')
df["Nettonennleistung der Einheit"] = df["Nettonennleistung der Einheit"].str.replace(',', '.')
df["Bruttoleistung der Einheit"] = df["Bruttoleistung der Einheit"].astype(float)
df["Nettonennleistung der Einheit"] = df["Nettonennleistung der Einheit"].astype(float)
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df["Bruttoleistung der Einheit"] = df["Bruttoleistung der Einheit"].str.replace(',', '.')
#       2 df["Nettonennleistung der Einheit"] = df["Nettonennleistung der Einheit"].str.replace(',', '.')
#       3 df["Bruttoleistung der Einheit"] = df["Bruttoleistung der Einheit"].astype(float)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
df["Postleitzahl"] = df["Postleitzahl"].fillna(0)
df["Postleitzahl"] = df["Postleitzahl"].astype(int)
df["Gemeindeschlüssel"] = df["Gemeindeschlüssel"].fillna(0)
df["Gemeindeschlüssel"] = df["Gemeindeschlüssel"].astype(int)

# %%
df["Koordinate: Breitengrad (WGS84)"] = df["Koordinate: Breitengrad (WGS84)"].fillna(0)
df["Koordinate: Breitengrad (WGS84)"] = df["Koordinate: Breitengrad (WGS84)"].str.replace(',', '.')
df["Koordinate: Breitengrad (WGS84)"] = df["Koordinate: Breitengrad (WGS84)"].astype(float)

# %%
df["Koordinate: Längengrad (WGS84) )"] = df["Koordinate: Längengrad (WGS84)"].fillna(0)
df["Koordinate: Längengrad (WGS84)"] = df["Koordinate: Längengrad (WGS84)"].str.replace(',', '.')
df["Koordinate: Längengrad (WGS84)"] = df["Koordinate: Längengrad (WGS84)"].astype(float)

# %%
df["Anzahl der Solar-Module"] = df["Anzahl der Solar-Module"].fillna(0)
df["Anzahl der Solar-Module"] = df["Anzahl der Solar-Module"].astype(int)

# %%
df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].fillna(0)
df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].str.replace(',', '.')
df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 2
#       1 df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].fillna(0)
# ----> 2 df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].str.replace(',', '.')
#       3 df["Nabenhöhe der Windenergieanlage"] = df["Nabenhöhe der Windenergieanlage"].astype(float)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# ...

# %%
df["Rotordurchmesser der Windenergieanlage"] = df["Rotordurchmesser der Windenergieanlage"].fillna(0)
df["Rotordurchmesser der Windenergieanlage"] = df["Rotordurchmesser der Windenergieanlage"].str.replace(',', '.')
df["Rotordurchmesser der Windenergieanlage"] = df["Rotordurchmesser der Windenergieanlage"].astype(float)

# %%
df.dtypes
# Out:
# MaStR-Nr. der Einheit                              object
# Anzeige-Name der Einheit                           object
# Betriebs-Status                                    object
# Energieträger                                      object
# Bruttoleistung der Einheit                        float64
# Nettonennleistung der Einheit                     float64
# Inbetriebnahmedatum der Einheit            datetime64[ns]
# Registrierungsdatum der Einheit            datetime64[ns]
# Bundesland                                         object
# Postleitzahl                                        int64
# Ort                                                object
# Straße                                             object
# Hausnummer                                         object
# Gemarkung                                          object
# Flurstück                                          object
# Gemeindeschlüssel                                   int64
# ...

# %%
df(df[df["Lage der Einheit"] == "Windkraft auf See"].index, inplace=True)

# %%
df_clean =["Registrierungsdatum der Einheit" , "Straße", "Hausnummer" , "Gemarkung" , "Flurstück" , "Name des Windparks" , "Typenbezeichnung" , "Hauptbrennstoff der Einheit" , "Nutzbare Speicherkapazität in kWh"  , "Technologie der Stromerzeugung" , "Letzte Aktualisierung" , "Datum der endgültigen Stilllegung" , "Datum der geplanten Inbetriebnahme" ,  "MaStR-Nr. der Genehmigung" , "Name des Anschluss-Netzbetreibers" , "MaStR-Nr. des Anschluss-Netzbetreibers" , "Netzbetreiberprüfung" , "Spannungsebene" , "MaStR-Nr. der Lokation" , "MaStR-Nr. der EEG-Anlage" , "EEG-Anlagenschlüssel" , "Inbetriebnahmedatum der EEG-Anlage" , "Installierte Leistung der EEG-Anlage" ,  "MaStR-Nr. der KWK-Anlage" , "Inbetriebnahmedatum der KWK-Anlage" , "Elektrische KWK-Leistung" , "Thermische Nutzleistung in kW"]
df.drop(columns=df_clean, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[143], line 2
#       1 df_clean =["Registrierungsdatum der Einheit" , "Straße", "Hausnummer" , "Gemarkung" , "Flurstück" , "Name des Windparks" , "Typenbezeichnung" , "Hauptbrennstoff der Einheit" , "Nutzbare Speicherkapazität in kWh"  , "Technologie der Stromerzeugung" , "Letzte Aktualisierung" , "Datum der endgültigen Stilllegung" , "Datum der geplanten Inbetriebnahme" ,  "MaStR-Nr. der Genehmigung" , "Name des Anschluss-Netzbetreibers" , "MaStR-Nr. des Anschluss-Netzbetreibers" , "Netzbetreiberprüfung" , "Spannungsebene" , "MaStR-Nr. der Lokation" , "MaStR-Nr. der EEG-Anlage" , "EEG-Anlagenschlüssel" , "Inbetriebnahmedatum der EEG-Anlage" , "Installierte Leistung der EEG-Anlage" ,  "MaStR-Nr. der KWK-Anlage" , "Inbetriebnahmedatum der KWK-Anlage" , "Elektrische KWK-Leistung" , "Thermische Nutzleistung in kW"]
# ...

# %%
df.drop(columns="Registrierungsdatum der Einheit" , inplace=True)

# %%
df.columns
# Out:
# Index(['MaStR-Nr. der Einheit', 'Anzeige-Name der Einheit', 'Betriebs-Status',
#        'Energieträger', 'Bruttoleistung der Einheit',
#        'Nettonennleistung der Einheit', 'Inbetriebnahmedatum der Einheit',
#        'Bundesland', 'Postleitzahl', 'Ort', 'Gemeindeschlüssel',
#        'Koordinate: Breitengrad (WGS84)', 'Koordinate: Längengrad (WGS84)',
#        'Anzahl der Solar-Module', 'Hauptausrichtung der Solar-Module',
#        'Nabenhöhe der Windenergieanlage',
#        'Rotordurchmesser der Windenergieanlage',
#        'Hersteller der Windenergieanlage', 'Lage der Einheit',
#        'Name des Anlagenbetreibers (nur Org.)',
#        '\tMaStR-Nr. des Anlagenbetreibers',
#        'Volleinspeisung oder Teileinspeisung',
#        'Zuschlagnummer (EEG/KWK-Ausschreibung)',
#        'Koordinate: Längengrad (WGS84) )',
#        'NRotordurchmesser der Windenergieanlage'],
#       dtype='object')

# %%
df = df.drop(['Hersteller der Windenergieanlage', 'Name des Anlagenbetreibers (nur Org.)', '\tMaStR-Nr. des Anlagenbetreibers', 'Zuschlagnummer (EEG/KWK-Ausschreibung)'] , axis=1)
#df.drop(columns=columns_to_drop, inplace=True)
#df = df.drop(['Registrierungsdatum der Einheit','Straße','Hausnummer','Gemarkung','Flurstück','Name des Windparks','Hersteller der Windenergieanlage','Typenbezeichnung','Hauptbrennstoff der Einheit','Nutzbare Speicherkapazität in kWh','Technologie der Stromerzeugung','Letzte Aktualisierung','Datum der endgültigen Stilllegung','Datum der geplanten Inbetriebnahme','Name des Anlagenbetreibers (nur Org.)','\tMaStR-Nr. des Anlagenbetreibers','MaStR-Nr. der Genehmigung','Name des Anschluss-Netzbetreibers','MaStR-Nr. des Anschluss-Netzbetreibers','Netzbetreiberprüfung','Spannungsebene','MaStR-Nr. der Lokation','MaStR-Nr. der EEG-Anlage','EEG-Anlagenschlüssel','Inbetriebnahmedatum der EEG-Anlage','Installierte Leistung der EEG-Anlage','Zuschlagnummer (EEG/KWK-Ausschreibung)','MaStR-Nr. der KWK-Anlage','Inbetriebnahmedatum der KWK-Anlage','Elektrische KWK-Leistung','Thermische Nutzleistung in kW'], axis=1)

# %%
df = df.drop(["Koordinate: Längengrad (WGS84) )" , "NRotordurchmesser der Windenergieanlage"] , axis=1)

# %%
df.dtypes
# Out:
# MaStR-Nr. der Einheit                             object
# Anzeige-Name der Einheit                          object
# Betriebs-Status                                   object
# Energieträger                                     object
# Bruttoleistung der Einheit                       float64
# Nettonennleistung der Einheit                    float64
# Inbetriebnahmedatum der Einheit           datetime64[ns]
# Bundesland                                        object
# Postleitzahl                                       int64
# Ort                                               object
# Gemeindeschlüssel                                  int64
# Koordinate: Breitengrad (WGS84)                  float64
# Koordinate: Längengrad (WGS84)                   float64
# Anzahl der Solar-Module                            int64
# Hauptausrichtung der Solar-Module                 object
# Nabenhöhe der Windenergieanlage                  float64
# ...

# %%
df
# Out:
#       MaStR-Nr. der Einheit Anzeige-Name der Einheit Betriebs-Status  \
# 0           SEE987333197686        PV Maschinenhalle      In Betrieb
# 1           SEE900142280806             Wintergarten      In Betrieb
# 2           SEE950622581053                      Sol      In Betrieb
# 3           SEE987490315794                      Byd      In Betrieb
# 4           SEE967921459426                 Hausdach      In Betrieb
# ...                     ...                      ...             ...
# 24995       SEE989544154205                   Stall2      In Betrieb
# 24996       SEE932458982419                    57858      In Betrieb
# 24997       SEE984925713514                Stalldach      In Betrieb
# 24998       SEE975552487855                     Dach      In Betrieb
# 24999       SEE940494553968              PV Zimmerei      In Betrieb
#
#                   Energieträger  Bruttoleistung der Einheit  \
# 0      Solare Strahlungsenergie                       27.38
# ...
